# %%
import shutil

# Correct source and destination paths
source_folder = r"C:\Users\nidhi\Cold mail generator"
destination_folder = r"C:\Users\nidhi\OneDrive\Desktop\Cold mailgenerator"

# Move the folder
shutil.move(source_folder, destination_folder)

print("Folder moved successfully!")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File ~\Downloads\Lib\shutil.py:847, in move(src, dst, copy_function)
#     846 try:
# --> 847     os.rename(src, real_dst)
#     848 except OSError:
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\nidhi\\Cold mail generator' -> 'C:\\Users\\nidhi\\OneDrive\\Desktop\\Cold mailgenerator'
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# Cell In[5], line 8
#       5 destination_folder = r"C:\Users\nidhi\OneDrive\Desktop\Cold mailgenerator"
#       7 # Move the folder
# ----> 8 shutil.move(source_folder, destination_folder)
#      10 print("Folder moved successfully!")
#
# File ~\Downloads\Lib\shutil.py:865, in move(src, dst, copy_function)
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\nidhi\Cold mail generator
