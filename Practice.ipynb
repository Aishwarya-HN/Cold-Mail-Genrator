# %%
# !pip install -U langchain langchain-groq
# Out:
# Requirement already satisfied: langchain in c:\users\nidhi\downloads\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-groq in c:\users\nidhi\downloads\lib\site-packages (0.3.8)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\nidhi\downloads\lib\site-packages (from langchain) (0.3.79)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\nidhi\downloads\lib\site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\nidhi\downloads\lib\site-packages (from langchain) (0.4.34)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\nidhi\downloads\lib\site-packages (from langchain) (2.12.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\nidhi\downloads\lib\site-packages (from langchain) (2.0.44)
# Requirement already satisfied: requests<3,>=2 in c:\users\nidhi\downloads\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\nidhi\downloads\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: groq<1,>=0.30.0 in c:\users\nidhi\downloads\lib\site-packages (from langchain-groq) (0.32.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\nidhi\downloads\lib\site-packages (from groq<1,>=0.30.0->langchain-groq) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\nidhi\downloads\lib\site-packages (from groq<1,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\nidhi\downloads\lib\site-packages (from groq<1,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: sniffio in c:\users\nidhi\downloads\lib\site-packages (from groq<1,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\nidhi\downloads\lib\site-packages (from groq<1,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\nidhi\downloads\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\nidhi\downloads\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\nidhi\downloads\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\nidhi\downloads\lib\site-packages (from langsmith>=0.1.17->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\nidhi\downloads\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\nidhi\downloads\lib\site-packages (from langsmith>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nidhi\downloads\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in c:\users\nidhi\downloads\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\nidhi\downloads\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nidhi\downloads\lib\site-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nidhi\downloads\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nidhi\downloads\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nidhi\downloads\lib\site-packages (from requests<3,>=2->langchain) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in c:\users\nidhi\downloads\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: httpcore==1.* in c:\users\nidhi\downloads\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\nidhi\downloads\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\nidhi\downloads\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install chromadb
# Out:
# Collecting chromadb
#   Using cached chromadb-1.1.1-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: build>=1.0.3 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (2.12.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\nidhi\downloads\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.37.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (2.3.2)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (4.15.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.23.1-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (1.37.0)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.37.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.37.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (1.75.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (5.0.0)
# Collecting typer>=0.9.0 (from chromadb)
#   Using cached typer-0.19.2-py3-none-any.whl.metadata (16 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-34.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (3.11.3)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\nidhi\downloads\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: packaging>=19.1 in c:\users\nidhi\downloads\lib\site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in c:\users\nidhi\downloads\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\nidhi\downloads\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\nidhi\downloads\lib\site-packages (from httpx>=0.27.0->chromadb) (4.10.0)
# Requirement already satisfied: certifi in c:\users\nidhi\downloads\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\nidhi\downloads\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in c:\users\nidhi\downloads\lib\site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\nidhi\downloads\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\nidhi\downloads\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\nidhi\downloads\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\nidhi\downloads\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\nidhi\downloads\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.27.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\nidhi\downloads\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\nidhi\downloads\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Using cached google_auth-2.41.1-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\nidhi\downloads\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\nidhi\downloads\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.5)
# Requirement already satisfied: requests-oauthlib in c:\users\nidhi\downloads\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3<2.4.0,>=1.24.2 in c:\users\nidhi\downloads\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\nidhi\downloads\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in c:\users\nidhi\downloads\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\nidhi\downloads\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.32.1)
# Requirement already satisfied: sympy in c:\users\nidhi\downloads\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\nidhi\downloads\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\nidhi\downloads\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in c:\users\nidhi\downloads\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in c:\users\nidhi\downloads\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.37.0)
# Collecting opentelemetry-semantic-conventions==0.58b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Using cached opentelemetry_semantic_conventions-0.58b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\nidhi\downloads\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\nidhi\downloads\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nidhi\downloads\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in c:\users\nidhi\downloads\lib\site-packages (from pydantic>=1.9->chromadb) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\nidhi\downloads\lib\site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\nidhi\downloads\lib\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\nidhi\downloads\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\nidhi\downloads\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.35.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\nidhi\downloads\lib\site-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\nidhi\downloads\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\nidhi\downloads\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\nidhi\downloads\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\nidhi\downloads\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\nidhi\downloads\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\nidhi\downloads\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\nidhi\downloads\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\nidhi\downloads\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: filelock in c:\users\nidhi\downloads\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\nidhi\downloads\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.9.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\nidhi\downloads\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\nidhi\downloads\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nidhi\downloads\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.3)
# Requirement already satisfied: sniffio>=1.1 in c:\users\nidhi\downloads\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\nidhi\downloads\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\nidhi\downloads\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nidhi\downloads\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\nidhi\downloads\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\nidhi\downloads\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Using cached chromadb-1.1.1-cp39-abi3-win_amd64.whl (19.8 MB)
# Using cached kubernetes-34.1.0-py2.py3-none-any.whl (2.0 MB)
# Using cached onnxruntime-1.23.1-cp312-cp312-win_amd64.whl (13.5 MB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.37.0-py3-none-any.whl (19 kB)
# Using cached opentelemetry_sdk-1.37.0-py3-none-any.whl (131 kB)
# Using cached opentelemetry_semantic_conventions-0.58b0-py3-none-any.whl (207 kB)
# Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl (2.7 MB)
# Using cached typer-0.19.2-py3-none-any.whl (46 kB)
# Using cached google_auth-2.41.1-py2.py3-none-any.whl (221 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Installing collected packages: google-auth, coloredlogs, typer, tokenizers, opentelemetry-semantic-conventions, onnxruntime, kubernetes, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
# Successfully installed chromadb-1.1.1 coloredlogs-15.0.1 google-auth-2.41.1 kubernetes-34.1.0 onnxruntime-1.23.1 opentelemetry-exporter-otlp-proto-grpc-1.37.0 opentelemetry-sdk-1.37.0 opentelemetry-semantic-conventions-0.58b0 tokenizers-0.22.1 typer-0.19.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\nidhi\downloads\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\nidhi\downloads\lib\site-packages (from langchain) (0.3.79)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\nidhi\downloads\lib\site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\nidhi\downloads\lib\site-packages (from langchain) (0.4.34)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\nidhi\downloads\lib\site-packages (from langchain) (2.12.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\nidhi\downloads\lib\site-packages (from langchain) (2.0.44)
# Requirement already satisfied: requests<3,>=2 in c:\users\nidhi\downloads\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\nidhi\downloads\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\nidhi\downloads\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\nidhi\downloads\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\nidhi\downloads\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\nidhi\downloads\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\nidhi\downloads\lib\site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\nidhi\downloads\lib\site-packages (from langsmith>=0.1.17->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\nidhi\downloads\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\nidhi\downloads\lib\site-packages (from langsmith>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nidhi\downloads\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in c:\users\nidhi\downloads\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\nidhi\downloads\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nidhi\downloads\lib\site-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nidhi\downloads\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nidhi\downloads\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nidhi\downloads\lib\site-packages (from requests<3,>=2->langchain) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in c:\users\nidhi\downloads\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: anyio in c:\users\nidhi\downloads\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\nidhi\downloads\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\nidhi\downloads\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\nidhi\downloads\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\nidhi\downloads\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_groq import ChatGroq
from langchain.prompts import PromptTemplate

# Use a supported model instead of the deprecated one
llm = ChatGroq(
    api_key="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",
    model="llama-3.1-8b-instant"
)

prompt = PromptTemplate(
    input_variables=["question"],
    template="Answer clearly: {question}"
)
chain = prompt | llm

response = chain.invoke({"question": "Who was the first person to walk on the moon?"})
print(response.content)
# Out:
# The first person to walk on the moon was Neil Armstrong. He stepped onto the lunar surface on July 20, 1969, during the Apollo 11 mission.

# %%
# !pip install -U langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.3.31-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.78 in c:\users\nidhi\downloads\lib\site-packages (from langchain-community) (0.3.79)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in c:\users\nidhi\downloads\lib\site-packages (from langchain-community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\nidhi\downloads\lib\site-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\nidhi\downloads\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\nidhi\downloads\lib\site-packages (from langchain-community) (6.0.2)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.13.0-cp312-cp312-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\nidhi\downloads\lib\site-packages (from langchain-community) (9.1.2)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.11.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\nidhi\downloads\lib\site-packages (from langchain-community) (0.4.34)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\nidhi\downloads\lib\site-packages (from langchain-community) (2.3.2)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\nidhi\downloads\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.8.0-cp312-cp312-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.7.0-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.22.0-cp312-cp312-win_amd64.whl.metadata (77 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\nidhi\downloads\lib\site-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (0.3.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\nidhi\downloads\lib\site-packages (from langchain<2.0.0,>=0.3.27->langchain-community) (2.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\nidhi\downloads\lib\site-packages (from langchain-core<2.0.0,>=0.3.78->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\nidhi\downloads\lib\site-packages (from langchain-core<2.0.0,>=0.3.78->langchain-community) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\nidhi\downloads\lib\site-packages (from langchain-core<2.0.0,>=0.3.78->langchain-community) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\nidhi\downloads\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\nidhi\downloads\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\nidhi\downloads\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\nidhi\downloads\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\nidhi\downloads\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\nidhi\downloads\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\nidhi\downloads\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nidhi\downloads\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nidhi\downloads\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nidhi\downloads\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in c:\users\nidhi\downloads\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: anyio in c:\users\nidhi\downloads\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\nidhi\downloads\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\nidhi\downloads\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\nidhi\downloads\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.78->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nidhi\downloads\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in c:\users\nidhi\downloads\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<2.0.0,>=0.3.27->langchain-community) (2.41.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\nidhi\downloads\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.3.31-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 20.8 MB/s eta 0:00:00
# Downloading aiohttp-3.13.0-cp312-cp312-win_amd64.whl (451 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading pydantic_settings-2.11.0-py3-none-any.whl (48 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp312-cp312-win_amd64.whl (44 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.0-cp312-cp312-win_amd64.whl (46 kB)
# Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl (41 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.22.0-cp312-cp312-win_amd64.whl (87 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: propcache, mypy-extensions, multidict, marshmallow, httpx-sse, frozenlist, aiohappyeyeballs, yarl, typing-inspect, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain-community
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.0 aiosignal-1.4.0 dataclasses-json-0.6.7 frozenlist-1.8.0 httpx-sse-0.4.3 langchain-community-0.3.31 marshmallow-3.26.1 multidict-6.7.0 mypy-extensions-1.1.0 propcache-0.4.1 pydantic-settings-2.11.0 typing-inspect-0.9.0 yarl-1.22.0
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
